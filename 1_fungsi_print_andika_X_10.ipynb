# %% [markdown]
# <a href="https://colab.research.google.com/github/andikawhildan-cloud/KKA-X-10-Semester-1/blob/main/1_fungsi_print_andika_X_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #menampilkan teks bebas

# %%
print("Hello world!")
# Out:
# Hello world!

# %%
print("Shinta Roudlotul Hanafia")
# Out:
# Shinta Roudlotul Hanafia

# %% [markdown]
# #menampilkan nilai variabel

# %%
print ("Andika solikhul whildan")
# Out:
# Andika solikhul whildan

# %%
print ("black pink")
# Out:
# black pink

# %%
print ("usia""15")
# Out:
# usia15

# %%
namaSaudara = "safeea damayanti"

print(namaSaudara)
# Out:
# safeea damayanti

# %%
mataPelajaranFavorit = ("PPKN")

print(mataPelajaranFavorit)
# Out:
# PPKN

# %%
namasaudara = "safeea damayanti"
print( "Nama saudara: " + namaSaudara)
# Out:
# Nama saudara: safeea damayanti

# %%
nama_panggilan_siswa = "Whildan"

print("Nama panggilan siswa tersebut adalah", nama_panggilan_siswa)
# Out:
# Nama panggilan siswa tersebut adalah Whildan

# %%
print("Nama panggilan siswa tersebut adalah (nama_panggilan_siswa) loh!")
# Out:
# Nama panggilan siswa tersebut adalah (nama_panggilan_siswa) loh!

# %% [markdown]
# #Menampilkan Nilai Variabel dan Teks Bebas

# %%
harga_telur = 26000

print("Harga telur per 1 kg adalah", harga_telur)
# Out:
# Harga telur per 1 kg adalah 26000

# %%
harga_telur = 26000

print("Harga telur per 1 kg adalah" + str(harga_telur))
# Out:
# Harga telur per 1 kg adalah26000

# %%
nama_pembeli = "Rafael"

print("Nama pembeli telur adalah " + nama_pembeli)
# Out:
# Nama pembeli telur adalah Rafael

# %%
print(f"Nama pembeli telur adalah {nama_pembeli}")
# Out:
# Nama pembeli telur adalah Rafael

# %% [markdown]
# #Escape Character

# %%
print("Nama: Andika solikhul whildan")

print("Kelas: X.10")

print("No absen: 3")
# Out:
# Nama: Andika solikhul whildan
# Kelas: X.10
# No absen: 3

# %%
print("Nama\t\t: andika solikhul whildan\nkelas\t\t: X.10\nNo absen\t: 3")
# Out:
# Nama		: andika solikhul whildan
# kelas		: X.10
# No absen	: 3

# %%
print('Alnun')
# Out:
# Alnun

# %%
print("""Nama: Andika solikhul whildan

Kelas: X.10

No absen: 3""")
# Out:
# Nama: Andika solikhul whildan
#
# Kelas: X.10
#
# No absen: 3

# %%
print('Alnun')
# Out:
# Alnun

# %%
print("A inun")
# Out:
# A inun

# %%
print("A\"inun")
# Out:
# A"inun

# %%
print("Bu Shinta berkata,\"Makan sosis so nice\"")
# Out:
# Bu Shinta berkata,"Makan sosis so nice"

# %%
print('Bu Shinta berkata,"Makan sosis so nice."')
# Out:
# Bu Shinta berkata,"Makan sosis so nice."

# %% [markdown]
# #Parameter Fungsi

# %%
Namasiswa1="whildan"

Namasiswa2="fahmi"

# %%
print("Namasiswal,Namasiswa2")
# Out:
# Namasiswal,Namasiswa2

# %%
print('Mahasiswa1','Namasiswa2',sep="-")
# Out:
# Mahasiswa1-Namasiswa2

# %%
print('Namasiswal','Namasiswa2','Namasiswal',sep="*")
# Out:
# Namasiswal*Namasiswa2*Namasiswal

# %%
print('Namasiswal', end="*")

print('Namasiswa2')
# Out:
# Namasiswal*Namasiswa2
