# %% [markdown]
# <a href="https://colab.research.google.com/github/andikawhildan-cloud/KKA-X-10-Semester-1/blob/main/2_Tipe_Variabel_Andika_Solikhul_WhildannX_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama:Andika Solikhul Whildan
#
# Kelas:X.10
#
# No.absen:3

# %% [markdown]
# #KONSEP VARIABEL

# %%
print("andikawhildan@gmail.com")
print("andikawhildan@gmail.com")
print("andikawhildan@gmail.com")
# Out:
# andikawhildan@gmail.com
# andikawhildan@gmail.com
# andikawhildan@gmail.com

# %%
email_user_1 = "andikawhildan@gmail.com"

print(email_user_1)

print(email_user_1)

print(email_user_1)
# Out:
# andikawhildan@gmail.com
# andikawhildan@gmail.com
# andikawhildan@gmail.com

# %% [markdown]
# #Peraturan Penulisan Variabel

# %%
email_user_2 = "Keenan Akbar"

print(email_user_2)
# Out:
# Keenan Akbar

# %%
email_user_2 = "Keenan Akbar"

print(email_user_2)
# Out:
# Keenan Akbar

# %%
emailuser2 = "Yoga Armando"

print(emailuser2)
# Out:
# Yoga Armando

# %%
email user 3 = "Dimas Esa"

print(email user 3)
# Out:
#   File "/tmp/ipython-input-234693131.py", line 1
#     email user 3 = "Dimas Esa"
#           ^
# SyntaxError: invalid syntax

# %%
emailUser3 = "Dimas Esa"

print(emailUser3)
# Out:
# Dimas Esa

# %%
4_email_user = "Hanafi Naufal"
print(4_email_user)
# Out:
#   File "/tmp/ipython-input-1513168937.py", line 1
#     4_email_user = "Hanafi Naufal"
#      ^
# SyntaxError: invalid decimal literal

# %%
for = "Naufal Fajri"

print(for)
# Out:
#   File "/tmp/ipython-input-1274762644.py", line 1
#     for = "Naufal Fajri"
#         ^
# SyntaxError: invalid syntax

# %%
For = "Naufal Fajri"

print(For)
# Out:
# Naufal Fajri

# %%
print = "Alif Nadya"
print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3121028777.py in <cell line: 0>()
#       1 print = "Alif Nadya"
# ----> 2 print(print)
#
# TypeError: 'str' object is not callable

# %%
Print = "Alif Nadya"
print(Print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1777838563.py in <cell line: 0>()
#       1 Print = "Alif Nadya"
# ----> 2 print(Print)
#
# TypeError: 'str' object is not callable

# %%
_ = "Azka Alifta"

# %%
print(_)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3119395983.py in <cell line: 0>()
# ----> 1 print(_)
#
# TypeError: 'str' object is not callable

# %%
_ = "Kenzo Aliando"

# %%
print(_)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3119395983.py in <cell line: 0>()
# ----> 1 print(_)
#
# TypeError: 'str' object is not callable

# %% [markdown]
# #Assignment

# %%
usia_rafa = 60

print (usia_rafa)
# Out:
# 60

# %%
berat_badan_farel, berat_badan_fahmi = 60, 65
print (berat_badan_fahmi)
print (berat_badan_farel)
# Out:
# 65
# 60

# %%
berat_badan_farel, berat_badan_fahmi = 60, 65,
print(berat_badan_farel)
print(berat_badan_fahmi)
# Out:
# 60
# 65

# %%
nilai_kka_naufa = nilai_kka_ridju = 99
print(nilai_kka_naufa)
print(nilai_kka_ridju)
# Out:
# 99
# 99

# %% [markdown]
# #Cara penulisan Operator Aritmatika pada Python

# %%
print(8+3)
# Out:
# 11

# %%
iphone_rafa = 8
iphone_bela = 3

print(iphone_rafa + iphone_bela)
# Out:
# 11

# %%
total_iphone = 8 + 3

print(total_iphone)
# Out:
# 11

# %%
iphone_rafa = 8
iphone_bela = 3

total_iphone = iphone_rafa + iphone_bela

print(total_iphone)
# Out:
# 11

# %% [markdown]
# #Tipe-tipe Variabel pada Python

# %%
x = "irkham gantenk"
print(x)
type(x)
# Out:
# irkham gantenk
# str

# %%
q = 0.5
print(q)
type(q)
# Out:
# 0.5
# float

# %%
p = 0
print(p)
type(p)
# Out:
# 0
# int

# %%
r = False
print(r)
type(r)
# Out:
# False
# bool

# %%
s = "False"
print(r)
type(r)
# Out:
# False
# bool

# %%
t = -6
print(t)
type(t)
# Out:
# -6
# int

# %%
u = -6.5
print(u)
type(u)
# Out:
# -6.5
# float

# %%
v =  "-6.5"
print(v)
type(v)
# Out:
# -6.5
# str

# %% [markdown]
# #Pengubahan Tipe Variabel

# %%
a = 5
print(a)
type(a)
# Out:
# 5
# int

# %% [markdown]
# #Operator Perbandingan

# %%
print(5 > 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-754879031.py in <cell line: 0>()
# ----> 1 print(5 > 3)
#
# TypeError: 'str' object is not callable

# %%
print(5 < 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1893027415.py in <cell line: 0>()
# ----> 1 print(5 < 3)
#
# TypeError: 'str' object is not callable

# %%
print(5 >= 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3496874941.py in <cell line: 0>()
# ----> 1 print(5 >= 5)
#
# TypeError: 'str' object is not callable

# %%
print(6 >= 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3202447789.py in <cell line: 0>()
# ----> 1 print(6 >= 5)
#
# TypeError: 'str' object is not callable

# %% [markdown]
# #Operator Logika

# %%
print( 8 > 7 and 6 == 6 )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1188772128.py in <cell line: 0>()
# ----> 1 print( 8 > 7 and 6 == 6 )
#
# TypeError: 'str' object is not callable

# %%
print( 5 > 2 or 4 <= 4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3661064696.py in <cell line: 0>()
# ----> 1 print( 5 > 2 or 4 <= 4)
#
# TypeError: 'str' object is not callable

# %%
print (not( 5 < 2 or 4 >= 4 ))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2766947869.py in <cell line: 0>()
# ----> 1 print (not( 5 < 2 or 4 >= 4 ))
#
# TypeError: 'str' object is not callable

# %%
a = 10
b = 20
c = 30

print(not(a > b and a != c))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3287380048.py in <cell line: 0>()
#       3 c = 30
#       4
# ----> 5 print(not(a > b and a != c))
#
# TypeError: 'str' object is not callable

# %%
print( not( 10 == a or c <= 31 ))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1722003108.py in <cell line: 0>()
# ----> 1 print( not( 10 == a or c <= 31 ))
#
# TypeError: 'str' object is not callable

# %%
nilai_kka = 76
kkm_kka = 75

print(nilai_kka >= kkm_kka)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2050121356.py in <cell line: 0>()
#       2 kkm_kka = 75
#       3
# ----> 4 print(nilai_kka >= kkm_kka)
#
# TypeError: 'str' object is not callable
